# %%
import cv2
from bovw import BOVW
import pandas
from typing import *
from PIL import Image
import matplotlib.pyplot as plt 
from main import Dataset, run_final_pipeline, run_BOVW_experiment
from IPython.display import clear_output

print("Loading Train Dataset...")
data_train = Dataset(ImageFolder="../places_reduced/train")

print("Loading Test Dataset...")
data_test = Dataset(ImageFolder="../places_reduced/val")

from fisher_vector import final_mod1

final_acc2, final_data2 = final_mod1(data_train,data_test)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import cv2
# ----> 2 from bovw import BOVW
#       3 import pandas
#       4 from typing import *
#
# ModuleNotFoundError: No module named 'bovw'
